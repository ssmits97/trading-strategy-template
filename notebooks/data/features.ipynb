# %% [markdown]
# # S&P500 Features
#
# Let's see how our features turned out

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('../../data/features/sp500_basics.csv', parse_dates=['Date'])
df = df.set_index('Date')
df
# Out:
#              returns      logs  Consumer Price Index  Long Interest Rate
# Date
# 2000-01-01       NaN  7.262341                168.80                6.66
# 2000-02-01 -0.025758  7.236246                169.80                6.52
# 2000-03-01  0.038405  7.273932                171.20                6.26
# 2000-04-01  0.013278  7.287123                171.30                5.99
# 2000-05-01 -0.029343  7.257341                171.50                6.44
# ...              ...       ...                   ...                 ...
# 2017-12-01  0.027271  7.887712                246.52                2.40
# 2018-01-01  0.047089  7.933725                247.87                2.58
# 2018-02-01 -0.030339  7.902916                248.99                2.86
# 2018-03-01 -0.000883  7.902032                249.55                2.84
# 2018-04-01 -0.022414  7.879363                249.84                2.80
#
# [220 rows x 4 columns]

# %%
df[['returns', 'logs', 'Long Interest Rate']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Consumer Price Index'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
mu, std = stats.norm.fit(df['returns'].dropna())

plt.hist(df['returns'], density=True)

x = np.linspace(df['returns'].min(), df['returns'].max(), 1000)
y = stats.norm.pdf(x, mu, std)
plt.plot(x, y)

plt.show()

# %% [markdown]
# Our features do not look weird.
# However, we see that our returns are not normally distributed.
# We cannot use the normal distribution for our returns
